# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

import warnings
warnings.filterwarnings('ignore')


df1=pd.read_csv('TSLA.csv')
df1.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2018-11-23  22.290001  22.500000  21.703333  21.722000  21.722000
# 1  2018-11-26  21.666668  23.081333  21.666668  23.066668  23.066668
# 2  2018-11-27  22.670000  23.130667  22.366667  22.927999  22.927999
# 3  2018-11-28  23.066000  23.218666  22.813999  23.191334  23.191334
# 4  2018-11-29  23.133333  23.166668  22.636667  22.744667  22.744667
#
#       Volume
# 0   63039000
# 1  119881500
# 2   95374500
# 3   61914000
# 4   46210500

# %%
df1.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1257.000000  1257.000000  1257.000000  1257.000000  1257.000000
# mean    166.453786   170.240805   162.362461   166.404047   166.404047
# std     109.868083   112.255896   107.173014   109.721770   109.721770
# min      12.073333    12.445333    11.799333    11.931333    11.931333
# 25%      38.379333    39.633331    37.205334    38.146667    38.146667
# 50%     194.419998   198.750000   189.919998   194.699997   194.699997
# 75%     250.050003   254.979996   244.449997   250.973328   250.973328
# max     411.470001   414.496674   405.666656   409.970001   409.970001
#
#              Volume
# count  1.257000e+03
# mean   1.338908e+08
# std    8.557588e+07
# min    2.940180e+07
# 25%    7.969650e+07
# 50%    1.092510e+08
# 75%    1.586991e+08
# max    9.140820e+08

# %%
# Calculate the median of the DataFrame for numeric columns only.
medians = df1.median(numeric_only=True)

# Round the median Series to two decimal places.
medians.round(2)
# Out:
# Open         1.944200e+02
# High         1.987500e+02
# Low          1.899200e+02
# Close        1.947000e+02
# Adj Close    1.947000e+02
# Volume       1.092510e+08
# dtype: float64

# %%
df1['Date']=pd.to_datetime(df1['Date'])

# %%
print("Minimum date value : {}".format(df1['Date'].min()))
print("Maximum date value : {}".format(df1['Date'].max()))
# Out:
# Minimum date value : 2018-11-23 00:00:00
# Maximum date value : 2023-11-21 00:00:00

# %%
#importing ploting libraries
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns
colors = ['#FF9900','#000000']
sns.set(palette=colors, font='Serif', style='white', rc={'axes.facecolor':'whitesmoke', 'figure.facecolor':'whitesmoke'})
sns.palplot(colors, size=2)

# %%
fig=plt.figure(figsize=(20,8))
ax=sns.lineplot(data=df1, x='Date',y='Open')
ax=sns.lineplot(data=df1, x='Date',y='Close', color=colors[1]);
for s in ['left','right','top','bottom']:
    ax.spines[s].set_visible(False)

plt.title("TESLA Stock value changes since 2010", size=20, weight='bold')
# Out:
# Text(0.5, 1.0, 'TESLA Stock value changes since 2010')

# %%
fig=plt.figure(figsize=(20,8))
ax=sns.lineplot(data=df1, x='Date',y='Volume')
#ax=sns.lineplot(data=df1, x='date',y='close', color=colors[1]);
for s in ['left','right','top','bottom']:
    ax.spines[s].set_visible(False)
plt.title("Tesla Stock volume", size=20, weight='bold')
# Out:
# Text(0.5, 1.0, 'Tesla Stock volume')

# %%
#integer columns
fig=plt.figure(figsize=(20,8), tight_layout=True)
plt.suptitle("Analysing the Numeric variables", size=20, weight='bold')
ax=fig.subplot_mosaic("""AB
                         CC
                         DE""")
sns.kdeplot(df1['High'], ax=ax['A'], color=colors[0], fill=True, linewidth=2)
sns.kdeplot(df1['Low'], ax=ax['B'], color=colors[1],fill=True, linewidth=2)
sns.kdeplot(df1['Open'], ax=ax['C'], color=colors[0],fill=True, linewidth=2)
sns.kdeplot(df1['Close'], ax=ax['D'], color=colors[1],fill=True, linewidth=2)
sns.kdeplot(df1['Volume'], ax=ax['E'], color=colors[0],fill=True, linewidth=2)
ax['B'].yaxis.set_visible(False)
ax['E'].yaxis.set_visible(False)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['D'].yaxis.label.set_alpha(0.5)
for s in ['left','right','top','bottom']:
    ax['A'].spines[s].set_visible(False)
    ax['B'].spines[s].set_visible(False)
    ax['C'].spines[s].set_visible(False)
    ax['D'].spines[s].set_visible(False)
    ax['E'].spines[s].set_visible(False)

# %%
#integer columns
fig=plt.figure(figsize=(20,8), tight_layout=True)
plt.suptitle("Boxplot the Numeric variables", size=20, weight='bold')
ax=fig.subplot_mosaic("""AB
                         CC
                         DE""")
sns.boxplot(df1['High'], ax=ax['A'], color=colors[0])
sns.boxplot(df1['Low'], ax=ax['B'], color=colors[1])
sns.boxplot(df1['Open'], ax=ax['C'], color=colors[0])
sns.boxplot(df1['Close'], ax=ax['D'], color=colors[1])
sns.boxplot(df1['Volume'], ax=ax['E'], color=colors[1])
ax['B'].yaxis.set_visible(False)
ax['E'].yaxis.set_visible(False)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['A'].yaxis.label.set_alpha(0.5)
ax['C'].yaxis.label.set_alpha(0.5)
ax['D'].yaxis.label.set_alpha(0.5)
for s in ['left','right','top','bottom']:
    ax['A'].spines[s].set_visible(False)
    ax['B'].spines[s].set_visible(False)
    ax['C'].spines[s].set_visible(False)
    ax['D'].spines[s].set_visible(False)
    ax['E'].spines[s].set_visible(False)

# %%
# we need to predict the closing price of the stock, lets us consider 'Close' feature as the Target variable. 
sns.pairplot(df1,corner=True)

# %%
df1.corr()['Close']
# Out:
# Date         0.762276
# Open         0.998232
# High         0.999207
# Low          0.999292
# Close        1.000000
# Adj Close    1.000000
# Volume      -0.417635
# Name: Close, dtype: float64

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1257 entries, 0 to 1256
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       1257 non-null   datetime64[ns]
#  1   Open       1257 non-null   float64
#  2   High       1257 non-null   float64
#  3   Low        1257 non-null   float64
#  4   Close      1257 non-null   float64
#  5   Adj Close  1257 non-null   float64
#  6   Volume     1257 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 68.9 KB

# %%
from scipy.stats import shapiro
import matplotlib.pyplot as plt
import seaborn as sns

int_cols = df1.select_dtypes(include=['int', 'float']).columns.to_list()

for i in int_cols:
    _, p_value = shapiro(df1[i])
    if p_value < 0.05:
        print("Feature {} is normally distributed".format(i))
    else:
        print("Feature {} is not normally distributed".format(i))
        
    print("Normality test p-value for feature - {} is {}".format(i, round(p_value, 3)))
# Out:
# Feature Open is normally distributed
# Normality test p-value for feature - Open is 0.0
# Feature High is normally distributed
# Normality test p-value for feature - High is 0.0
# Feature Low is normally distributed
# Normality test p-value for feature - Low is 0.0
# Feature Close is normally distributed
# Normality test p-value for feature - Close is 0.0
# Feature Adj Close is normally distributed
# Normality test p-value for feature - Adj Close is 0.0
# Feature Volume is normally distributed
# Normality test p-value for feature - Volume is 0.0

# %%
fig=plt.figure(figsize=(15,8))
sns.heatmap(df1.corr(), annot=True, cmap=[colors[0],colors[1]], linecolor='white', linewidth=2 )
# Out:
# <Axes: >

# %%
X=df1[['Volume','Open']]
y=df1['Close']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, shuffle=False, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test =scaler.transform(X_test)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error
from sklearn import set_config
model = LinearRegression()
model.fit(X_train,y_train)
set_config(display='diagram')
pred=model.predict(X_test)
sc=np.round(model.score(X_test, y_test),2) * 100
r2=np.round(r2_score(y_test,pred),2)
mse=np.round(mean_squared_error(y_test,pred),2)
mae=np.round(mean_squared_error(y_test,pred),2)

# %%
fig = plt.figure(figsize=(15, 8))
p = pd.Series(pred, index=y_test.index)
plt.plot(y_test)
plt.plot(p)
plt.legend(['y_test', 'predicted'])
plt.title("Compare test and predicted values", size=20, weight='bold')
plt.text(x=800000, y=600, s='Accuracy score : {} %'.format(sc))
plt.text(x=800000, y=580, s='R2 Score : {}'.format(r2))
plt.text(x=800000, y=560, s='Mean Squared error : {}'.format(mse))
plt.text(x=800000, y=540, s='Mean Absolute error : {}'.format(mae))

# Save the figure to a file without displaying it
plt.savefig('plot.png')

# Close the figure to prevent it from being displayed
plt.close()

# %%
X=df1[['Open','High']]
y=df1['Close']
length=100
#from sklearn.model_selection import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, shuffle=False, random_state=42)
training_set = X.iloc[:1000].values
test_set = X.iloc[1000:].values
# Feature Scaling
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0, 1))
training_set_scaled = sc.fit_transform(training_set)
test_set_scaled=sc.transform(test_set)
# Creating a data structure with 60 time-steps and 1 output
X_train = []
y_train = []
for i in range(length, len(training_set)):
    X_train.append(training_set_scaled[i-length:i, 0])
    y_train.append(training_set_scaled[i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

X_test = []
y_test = []
for i in range(length, len(test_set)):
    X_test.append(test_set_scaled[i-length:i, 0])
    y_test.append(test_set_scaled[i, 0])
X_test, y_test = np.array(X_test), np.array(y_test)
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout
model = Sequential()
#Adding the first LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
model.add(Dropout(0.2))
# Adding a second LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a third LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50, return_sequences = True))
model.add(Dropout(0.2))
# Adding a fourth LSTM layer and some Dropout regularisation
model.add(LSTM(units = 50))
model.add(Dropout(0.2))
# Adding the output layer
model.add(Dense(units = 1))

# Compiling the RNN
model.compile(optimizer = 'adam', loss = 'mean_squared_error')

# Fitting the RNN to the Training set
model.fit(X_train, y_train, validation_data=(X_test,y_test),epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 29/29 [==============================] - 5s 76ms/step - loss: 0.0375 - val_loss: 0.0070
# Epoch 2/100
# 29/29 [==============================] - 1s 49ms/step - loss: 0.0091 - val_loss: 0.0046
# Epoch 3/100
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0071 - val_loss: 0.0042
# Epoch 4/100
# 29/29 [==============================] - 2s 57ms/step - loss: 0.0076 - val_loss: 0.0037
# Epoch 5/100
# Epoch 89/100
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0019 - val_loss: 7.6158e-04
# Epoch 90/100
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0018 - val_loss: 0.0011
# Epoch 91/100
# 29/29 [==============================] - 2s 56ms/step - loss: 0.0019 - val_loss: 7.5839e-04
# Epoch 92/100
# 29/29 [==============================] - 2s 53ms/step - loss: 0.0021 - val_loss: 0.0011
# Epoch 93/100
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0019 - val_loss: 7.8049e-04
# Epoch 94/100
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0020 - val_loss: 7.6006e-04
# Epoch 95/100
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0019 - val_loss: 0.0017
# Epoch 96/100
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0023 - val_loss: 7.5914e-04
# Epoch 97/100
# 29/29 [==============================] - 1s 52ms/step - loss: 0.0019 - val_loss: 9.1546e-04
# Epoch 98/100
# 29/29 [==============================] - 1s 51ms/step - loss: 0.0020 - val_loss: 8.8621e-04
# Epoch 99/100
# 29/29 [==============================] - 1s 50ms/step - loss: 0.0016 - val_loss: 0.0012
# Epoch 100/100
# 29/29 [==============================] - 2s 52ms/step - loss: 0.0022 - val_loss: 0.0016

# %%
loss = pd.DataFrame(model.history.history)
fig=plt.figure(figsize=(15,8))
plt.title("Validation loss Vs Trainiinverse_transformss", size=20, weight='bold')
plt.plot(loss)
# Out:
# [<matplotlib.lines.Line2D at 0x2215c985030>,
#  <matplotlib.lines.Line2D at 0x2215c985060>]

# %%
pred=model.predict(X_test)
test=pd.DataFrame(columns=['test','pred'])
test['test']=y_test
test['pred']=pred.flatten()
test
# Out:
# 5/5 [==============================] - 1s 17ms/step
#          test      pred
# 0    0.437201  0.478436
# 1    0.447341  0.469977
# 2    0.427862  0.466476
# 3    0.430341  0.465119
# 4    0.436275  0.464569
# ..        ...       ...
# 152  0.568900  0.552361
# 153  0.569401  0.564579
# 154  0.550647  0.580977
# 155  0.555755  0.591405
# 156  0.558259  0.595201
#
# [157 rows x 2 columns]

# %%
fig=plt.figure(figsize=(20,8))
plt.title("Test vs Predicted value", size=20, weight='bold')
plt.plot(test)
plt.legend(['test','predict'])
r2=np.round(r2_score(y_test,pred),2)
mse=np.round(mean_squared_error(y_test,pred),2)
mae=np.round(mean_squared_error(y_test,pred),2)
plt.text(x=500, y=1.5,s='R2 Score : {}'.format(r2))
plt.text(x=500, y=1.35,s='Mean Squared error : {}'.format(mse))
plt.text(x=500, y=1.25,s='Mean Absolute error : {}'.format(mae))
# Out:
# Text(500, 1.25, 'Mean Absolute error : 0.0')

# %%
from prophet import Prophet
df_p = df1[['Date','Close']]
df_p.columns = ['ds', 'y']

split_percentage = 0.73
split_index = int(df_p.shape[0] * split_percentage)
train = df_p.loc[df_p.index<=split_index].copy()
test=df_p.loc[df_p.index>split_index].copy()
train.set_index('ds',inplace=True)
test.set_index('ds',inplace=True)
train.reset_index(inplace=True)
test.reset_index(inplace=True)

train = df_p.iloc[:split_index]
test = df_p.iloc[split_index:]

# Model creation
model = Prophet()
model.fit(train)

# Model prediction
pred = model.predict(test)
# Out:
# 18:08:19 - cmdstanpy - INFO - Chain [1] start processing
# 18:08:19 - cmdstanpy - INFO - Chain [1] done processing

# %%
test_pred=pd.DataFrame(columns=['ds','test','predict','pred_lower','pred_high'], index=test.index)
test_pred['test']=test['y']
test_pred['ds']=test['ds']
test_pred['predict']=pred['yhat']
test_pred['pred_lower']=pred['yhat_lower']
test_pred['pred_high']=pred['yhat_upper']

# %%
# Merge test and pred DataFrames on 'ds' to align the prediction with the actual values
test_pred = test.merge(pred[['ds', 'yhat', 'yhat_lower', 'yhat_upper']], on='ds', how='inner')
test_pred.rename(columns={'yhat': 'predict', 'y': 'test'}, inplace=True)

# Calculate the metrics
r2 = np.round(r2_score(test_pred['test'], test_pred['predict']), 2)
mse = np.round(mean_squared_error(test_pred['test'], test_pred['predict']), 2)
mae = np.round(mean_absolute_error(test_pred['test'], test_pred['predict']), 2)

# Plotting Test vs Predicted
fig = plt.figure(figsize=(15, 8))
plt.title("Test Vs Prediction", size=20, weight='bold')
sns.lineplot(data=test_pred, x='ds', y='test', label='Test')
sns.lineplot(data=test_pred, x='ds', y='predict', label='Predict')

# Get the latest date for placing the text annotations on the plot
latest_date = test_pred['ds'].max()
# Convert the latest date to matplotlib's date format for plotting
latest_date_num = mdates.date2num(latest_date)

# Annotate the plot with the R2 and error metrics
plt.text(x=latest_date_num, y=test_pred['test'].min(), s=f'R2 Score: {r2}')
plt.text(x=latest_date_num, y=test_pred['test'].min() - 20, s=f'Mean Squared Error: {mse}')
plt.text(x=latest_date_num, y=test_pred['test'].min() - 40, s=f'Mean Absolute Error: {mae}')

# Set the x-axis to display dates properly
plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m'))
plt.gca().xaxis.set_major_locator(mdates.MonthLocator())

# Rotate date labels for better readability
plt.xticks(rotation=45)

plt.show()

# %%
fig=plt.figure(figsize=(15,8))
plt.title("Test Vs Prediction", size=20, weight='bold')
sns.lineplot(data=train,x='ds',y='y')
sns.lineplot(data=test_pred,x='ds',y='predict')
sns.lineplot(data=test_pred,x='ds',y='test', alpha=0.5, ls='--', color='black')

r2=np.round(r2_score(test_pred['test'],test_pred['predict']),2)
mse=np.round(mean_squared_error(test_pred['test'],test_pred['predict']),2)
mae=np.round(mean_squared_error(test_pred['test'],test_pred['predict']),2)
plt.text(x=mdates.datestr2num('2015'), y=300,s='R2 Score : {}'.format(r2))
plt.text(x=mdates.datestr2num('2015'), y=260,s='Mean Squared error : {}'.format(mse))
plt.text(x=mdates.datestr2num('2015'), y=220,s='Mean Absolute error : {}'.format(mae))
plt.legend(['Train','Predict','Test'])

# %%
#Long Short-Term Memory networks (LSTMs)

# %%
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dense, Dropout

# Assuming df1 is your preprocessed dataset with 'Date' and 'Close' columns
# Convert 'Date' to datetime and sort the DataFrame by date
df1['Date'] = pd.to_datetime(df1['Date'])
df1.sort_values('Date', inplace=True)

# Scale the 'Close' prices
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_close = scaler.fit_transform(df1['Close'].values.reshape(-1, 1))

# Function to create a dataset for LSTM
def create_dataset(data, time_step=1):
    X, Y = [], []
    for i in range(len(data) - time_step - 1):
        a = data[i:(i + time_step), 0]
        X.append(a)
        Y.append(data[i + time_step, 0])
    return np.array(X), np.array(Y)

# Create the LSTM dataset
time_step = 10
X, y = create_dataset(scaled_close, time_step)
X = X.reshape(X.shape[0], X.shape[1], 1)

# Split into train and test sets
train_size = int(len(X) * 0.8)
test_size = len(X) - train_size
X_train, X_test = X[0:train_size], X[train_size:len(X)]
y_train, y_test = y[0:train_size], y[train_size:len(y)]

# Build the LSTM model
model = Sequential()
model.add(LSTM(50, return_sequences=True, input_shape=(10, 1)))
model.add(LSTM(50, return_sequences=False))
model.add(Dense(25))
model.add(Dense(1))

# Compile the model
model.compile(optimizer='adam', loss='mean_squared_error')

# Train the model
model.fit(X_train, y_train, batch_size=1, epochs=10)

# Making predictions
train_predict = model.predict(X_train)
test_predict = model.predict(X_test)

# Inverse transform predictions
train_predict = scaler.inverse_transform(train_predict)
test_predict = scaler.inverse_transform(test_predict)

# Calculate RMSE performance metrics
train_rmse = np.sqrt(np.mean(train_predict - y_train)**2)
test_rmse = np.sqrt(np.mean(test_predict - y_test)**2)
# Out:
# Epoch 1/10
# 996/996 [==============================] - 5s 3ms/step - loss: 0.0035
# Epoch 2/10
# 996/996 [==============================] - 3s 3ms/step - loss: 0.0020
# Epoch 3/10
# 996/996 [==============================] - 3s 3ms/step - loss: 0.0016
# Epoch 4/10
# 996/996 [==============================] - 3s 3ms/step - loss: 9.5807e-04
# Epoch 5/10
# 996/996 [==============================] - 3s 3ms/step - loss: 8.6107e-04
# Epoch 6/10
# 996/996 [==============================] - 3s 3ms/step - loss: 7.4686e-04
# Epoch 7/10
# 996/996 [==============================] - 3s 3ms/step - loss: 6.8591e-04
# Epoch 8/10
# 996/996 [==============================] - 3s 3ms/step - loss: 7.6490e-04
# Epoch 9/10
# 996/996 [==============================] - 3s 3ms/step - loss: 6.6145e-04
# Epoch 10/10
# 996/996 [==============================] - 3s 3ms/step - loss: 6.9578e-04
# 32/32 [==============================] - 0s 1ms/step
# 8/8 [==============================] - 0s 2ms/step

# %%
import matplotlib.pyplot as plt

# Extract the actual prices from the scaled data
actual_prices = scaler.inverse_transform(scaled_close).reshape(-1)

# Combine train and test predictions for plotting
total_predictions = np.concatenate((train_predict, test_predict))
dates = df1['Date'].values

# Plotting Actual vs Predicted Prices
plt.figure(figsize=(15, 6))

# Actual prices
plt.subplot(1, 2, 1)
plt.plot(dates, actual_prices, label='Actual Prices', color='blue')

# Predicted prices for train set
train_dates = dates[:len(train_predict)]
plt.plot(train_dates, train_predict, label='Train Predictions', color='green')

# Predicted prices for test set
test_dates = dates[len(train_predict):len(train_predict) + len(test_predict)]
plt.plot(test_dates, test_predict, label='Test Predictions', color='red')

plt.title('Actual and Predicted Prices')
plt.xlabel('Date')
plt.ylabel('Prices')
plt.legend()

# Plotting RMSE Values
plt.subplot(1, 2, 2)
bar_width = 0.4
plt.bar('Train RMSE', train_rmse, bar_width, label='Train RMSE', color='orange')
plt.bar('Test RMSE', test_rmse, bar_width, label='Test RMSE', color='purple')

plt.title('RMSE Values')
plt.ylabel('RMSE')
plt.legend()

plt.tight_layout()
plt.show()
